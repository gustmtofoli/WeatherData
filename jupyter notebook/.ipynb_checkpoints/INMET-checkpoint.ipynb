# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/home/gustavo/Desenvolvimento/weatherdata/dados/janeiro_1980__janeiro_2018.csv")
print(data)
# Out:
#        Estacao      Data  Hora  Precipitacao  TempMaxima  TempMinima  \
# 0        83767  01/01/00     0           NaN        29.9         NaN
# 1        83767  01/01/00  1200          90.3         NaN        20.3
# 2        83767  02/01/00     0           NaN        29.0         NaN
# 3        83767  02/01/00  1200           0.0         NaN        18.5
# 4        83767  03/01/00     0           NaN        28.0         NaN
# 5        83767  03/01/00  1200           2.3         NaN        19.3
# 6        83767  04/01/00     0           NaN        29.4         NaN
# 7        83767  04/01/00  1200           0.6         NaN        19.3
# 8        83767  05/01/00     0           NaN        31.5         NaN
# 9        83767  05/01/00  1200           1.3         NaN        19.9
# 10       83767  06/01/00     0           NaN        31.9         NaN
# 11       83767  06/01/00  1200           0.0         NaN        21.2
# 12       83767  07/01/00     0           NaN        30.5         NaN
# ...

# %%
date = '20/05'
data = data[['Data', 'Hora', 'Precipitacao', 'TempMaxima', 'TempMinima']]
data[['Precipitacao', 'TempMaxima', 'TempMinima']].describe()
# Out:
#        Precipitacao   TempMaxima   TempMinima
# count   6280.000000  6280.000000  6275.000000
# mean       4.770398    28.470557    18.113402
# std       12.232855     4.223465     3.766784
# min        0.000000    10.100000     0.500000
# 25%        0.000000    26.100000    16.200000
# 50%        0.000000    29.100000    18.800000
# 75%        2.000000    31.500000    20.800000
# max      142.600000    39.200000    26.400000
